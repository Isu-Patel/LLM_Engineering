# %%
import os
from dotenv import load_dotenv
from my_scraper import fetch_website_contents
from IPython.display import Markdown, display
from openai import OpenAI

# %%
load_dotenv()
client = OpenAI(api_key=os.getenv('OPENAI_KEY'))

if not client.api_key:
   print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
elif not client.api_key.startswith("sk-proj-"):
   print("An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook")
elif client.api_key.strip() != client.api_key:
   print("An API key was found, but it looks like it might have space or tab characters at the start or end - please remove them")
else:
   print("API key found and looks good so far!")
# Out:
# API key found and looks good so far!

# %%
message = "Hello ChatGPT! This is my first ever message to you! Hi!"

messages = [{'role': "user", "content": message}]

messages
# Out:
# [{'role': 'user',
#   'content': 'Hello ChatGPT! This is my first ever message to you! Hi!'}]

# %%
openai = OpenAI()

response = client.chat.completions.create(model="gpt-5-nano", messages = messages)
response.choices[0].message.content
# Out:
# 'Hi there! Nice to meet you. I’m here to help with questions, writing, planning, coding, learning new topics, and more.\n\nA few things I can do:\n- Explain concepts in simple terms or go deep into details\n- Draft or edit emails, messages, essays, or posts\n- Help plan trips, events, or study schedules\n- Summarize articles or documents\n- Troubleshoot code and explain programming ideas\n- Translate or rephrase text, and adjust tone or style\n- Brainstorm ideas orSolve problems step by step\n\nIf you have a preference for tone (casual, formal, concise, detailed) or a specific goal, tell me. What would you like to do today?'

# %%
isu = fetch_website_contents()
